# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewHallam1/SIT724/blob/main/SIT724.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Additional installs as not included in Colab as a base package.

# !pip install pytorch_tabnet
# Out:
# Collecting pytorch_tabnet
#   Downloading pytorch_tabnet-4.1.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from pytorch_tabnet) (1.25.2)
# Requirement already satisfied: scikit_learn>0.21 in /usr/local/lib/python3.10/dist-packages (from pytorch_tabnet) (1.2.2)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_tabnet) (1.11.4)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.10/dist-packages (from pytorch_tabnet) (2.2.1+cu121)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.10/dist-packages (from pytorch_tabnet) (4.66.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>0.21->pytorch_tabnet) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>0.21->pytorch_tabnet) (3.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch_tabnet) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch_tabnet) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch_tabnet) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch_tabnet) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch_tabnet) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch_tabnet) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 57.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 69.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 94.7 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.9 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.5 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 15.8 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.5 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.3 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch_tabnet) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.0 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3->pytorch_tabnet) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3->pytorch_tabnet) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, pytorch_tabnet
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 pytorch_tabnet-4.1.0

# %%
# Import libraries and packages

import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import time
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn.inspection import permutation_importance
start = time.time()
import numpy
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, ConfusionMatrixDisplay
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.preprocessing import PowerTransformer
from sklearn.ensemble import StackingClassifier
from sklearn.model_selection import cross_val_score as cvs
from sklearn.model_selection import StratifiedShuffleSplit

#deep learning
from tensorflow.keras import layers
from tensorflow.keras import models
from keras.callbacks import EarlyStopping
import torch
from torch import nn
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.impute import SimpleImputer

# %%
#mounting google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **COLET DATA FILES**

# %%
#Getting all files for COLET

#setting file path from google drive
folder_path = '/content/drive/MyDrive/SIT724 Data/COLET'

#obtaining all files within this file path
files_xlsx = os.listdir(folder_path)

#all files
# Iterate over the files and print their names
for file in files_xlsx:
    file_path = os.path.join(folder_path, file)
    print(file_path)
# Out:
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_2.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_3.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_4.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_5.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_6.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_7.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_8.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_9.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_10.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_11.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_13.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_12.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_14.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_15.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_16.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_17.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_18.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_19.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_20.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_21.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_22.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_23.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_25.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_24.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_26.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_27.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_28.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_29.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_30.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_31.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_32.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_33.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_34.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_35.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_36.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_38.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_37.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_39.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_40.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_41.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_42.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_43.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_44.xlsx
# /content/drive/MyDrive/SIT724 Data/COLET/Task1_Subject_1.xlsx

# %%
#blank dataframe to write to
#we need one of these for each record type (i.e. 16) otherwise we are appending to differing columns
c_gaze_task1 = pd.DataFrame()
c_gaze_task2 = pd.DataFrame()
c_gaze_task3 = pd.DataFrame()
c_gaze_task4 = pd.DataFrame()
c_pupil_task1 = pd.DataFrame()
c_pupil_task2 = pd.DataFrame()
c_pupil_task3 = pd.DataFrame()
c_pupil_task4 = pd.DataFrame()
c_blinks_task1 = pd.DataFrame()
c_blinks_task2 = pd.DataFrame()
c_blinks_task3 = pd.DataFrame()
c_blinks_task4 = pd.DataFrame()
c_annotation_task1 = pd.DataFrame()
c_annotation_task2 = pd.DataFrame()
c_annotation_task3 = pd.DataFrame()
c_annotation_task4 = pd.DataFrame()

# %%
#Writing files into dataframes
df_cg1 = []

for file in files_xlsx:
    file_path = os.path.join(folder_path, file)
    data1 = pd.read_excel(file_path, sheet_name=0)
    file_name = os.path.basename(file_path)
    data1['file'] = file_name
    df_cg1.append(data1)

# Concatenate the list of DataFrames into a single DataFrame
c_gaze_task1 = pd.concat(df_cg1)

# %%
c_gaze_task1
# Out:
#       gaze_timestamp  world_index  confidence  norm_pos_x  norm_pos_y  \
# 0       91462.401110            0    0.999700    0.507389    0.634850
# 1       91462.404944            0    0.999901    0.506490    0.635390
# 2       91462.408709            0    0.999880    0.506632    0.634810
# 3       91462.413088            0    0.999357    0.506855    0.634965
# 4       91462.417473            0    0.999344    0.506882    0.635483
# ...              ...          ...         ...         ...         ...
# 8200     5444.341634          236    0.735939    0.548112    0.687153
# 8201     5444.345790          236    0.045619    0.718034    1.055603
# 8202     5444.350231          236    0.390900    0.501854    0.814781
# 8203     5444.353666          236    0.012059    0.763209    0.862900
# 8204     5444.357724          236    0.451749    0.507364    0.817766
#
#                             base_data  gaze_point_3d_x  gaze_point_3d_y  \
# 0      '91462.401039-0 91462.40118-1'         3.834305       -31.385085
# 1      '91462.408708-0 91462.40118-1'         3.539312       -31.240366
# 2      '91462.408708-0 91462.40871-1'         3.572247       -31.063236
# 3      '91462.417466-0 91462.40871-1'         3.644875       -31.147063
# 4     '91462.417466-0 91462.417481-1'         3.650566       -31.212725
# ...                               ...              ...              ...
# 8200            '5444.341633999999-0'        30.657984       -77.039853
# 8201            '5444.345789999999-1'       105.301620      -161.238478
# 8202            '5444.350230999999-0'         4.060156      -114.771992
# 8203                  '5444.353666-1'       119.821240      -104.195407
# 8204           '5444.3577239999995-0'         7.157517      -116.273491
#
#       gaze_point_3d_z  eye_center0_3d_x  ...  gaze_normal0_x  gaze_normal0_y  \
# 0          182.714977         17.063377  ...       -0.063036       -0.200221
# 1          181.338755         17.063377  ...       -0.064880       -0.201583
# 2          180.884473         17.063377  ...       -0.064880       -0.201583
# 3          181.216796         17.063377  ...       -0.064426       -0.201700
# 4          181.083513         17.063377  ...       -0.064426       -0.201700
# ...               ...               ...  ...             ...             ...
# 8200       346.140198        228.951321  ...       -0.396587       -0.120667
# 8201       225.198142               NaN  ...             NaN             NaN
# 8202       326.792695        228.951321  ...       -0.449782       -0.196131
# 8203       230.318571               NaN  ...             NaN             NaN
# 8204       328.038192        228.951321  ...       -0.443588       -0.199134
#
#       gaze_normal0_z  eye_center1_3d_x  eye_center1_3d_y  eye_center1_3d_z  \
# 0           0.977721        -40.264899         12.956560        -20.449919
# 1           0.977320        -40.264899         12.956560        -20.449919
# 2           0.977320        -40.264899         12.956560        -20.449919
# 3           0.977326        -40.264899         12.956560        -20.449919
# 4           0.977326        -40.264899         12.956560        -20.449919
# ...              ...               ...               ...               ...
# 8200        0.910032               NaN               NaN               NaN
# 8201             NaN       -206.691192        -18.574326       -138.542734
# 8202        0.871337               NaN               NaN               NaN
# 8203             NaN       -206.691192        -18.574326       -138.542734
# 8204        0.873828               NaN               NaN               NaN
#
#       gaze_normal1_x  gaze_normal1_y  gaze_normal1_z                  file
# 0           0.207303       -0.215924        0.954150  Task1_Subject_2.xlsx
# 1           0.207303       -0.215924        0.954150  Task1_Subject_2.xlsx
# 2           0.207924       -0.215176        0.954184  Task1_Subject_2.xlsx
# 3           0.207924       -0.215176        0.954184  Task1_Subject_2.xlsx
# 4           0.208053       -0.216031        0.953963  Task1_Subject_2.xlsx
# ...              ...             ...             ...                   ...
# 8200             NaN             NaN             NaN  Task1_Subject_1.xlsx
# 8201        0.623986       -0.285328        0.727482  Task1_Subject_1.xlsx
# 8202             NaN             NaN             NaN  Task1_Subject_1.xlsx
# 8203        0.653025       -0.171242        0.737723  Task1_Subject_1.xlsx
# 8204             NaN             NaN             NaN  Task1_Subject_1.xlsx
#
# [424632 rows x 22 columns]

# %%
#Writing files into dataframes
df_cg2 = []

for file in files_xlsx:
    file_path = os.path.join(folder_path, file)
    #sheet name is how we are identifying different datasets, this needs to be updated each time
    data2 = pd.read_excel(file_path, sheet_name=1)
    file_name = os.path.basename(file_path)
    data2['file'] = file_name
    df_cg2.append(data2)

# Concatenate the list of DataFrames into a single DataFrame
c_gaze_task2 = pd.concat(df_cg2)

# %%
c_gaze_task2
# Out:
#       gaze_timestamp  world_index  confidence  norm_pos_x  norm_pos_y  \
# 0       91264.822762            0    0.999341    0.513221    0.650533
# 1       91264.826794            0    0.999365    0.512855    0.650369
# 2       91264.830759            0    0.999403    0.512287    0.650039
# 3       91264.834771            0    0.999075    0.512570    0.649921
# 4       91264.838779            0    0.998936    0.512252    0.649898
# ...              ...          ...         ...         ...         ...
# 6865     4687.635396          245    0.998507    0.570797    0.838661
# 6866     4687.639989          245    0.998679    0.570966    0.837511
# 6867     4687.644404          246    0.998769    0.571118    0.838497
# 6868     4687.648476          246    0.998697    0.570709    0.838814
# 6869     4687.652637          246    0.998733    0.570676    0.837892
#
#                                       base_data  gaze_point_3d_x  \
# 0               '91264.824851-0 91264.820672-1'         4.708798
# 1               '91264.824851-0 91264.828737-1'         4.640139
# 2                '91264.83278-0 91264.828737-1'         4.477171
# 3                '91264.83278-0 91264.836762-1'         4.530618
# 4               '91264.840796-0 91264.836762-1'         4.440042
# ...                                         ...              ...
# 6865  '4687.633688999999-0 4687.637103999999-1'        11.393278
# 6866        '4687.642874-0 4687.637103999999-1'        11.431938
# 6867              '4687.642874-0 4687.645933-1'        11.440781
# 6868              '4687.651018-0 4687.645933-1'        11.352198
# 6869              '4687.651018-0 4687.654256-1'        11.349805
#
#       gaze_point_3d_y  gaze_point_3d_z  eye_center0_3d_x  ...  gaze_normal0_x  \
# 0          -28.734923       153.924007         19.530167  ...       -0.082408
# 1          -28.859883       154.725318         19.530167  ...       -0.082408
# 2          -28.690866       154.082308         19.530167  ...       -0.083620
# 3          -28.559386       153.466812         19.530167  ...       -0.083620
# 4          -28.488006       153.103190         19.530167  ...       -0.084297
# ...               ...              ...               ...  ...             ...
# 6865       -32.863788        86.482333         19.395493  ...       -0.067855
# 6866       -32.805362        86.614668         19.395493  ...       -0.067487
# 6867       -32.848767        86.477916         19.395493  ...       -0.067487
# 6868       -32.796111        86.267341         19.395493  ...       -0.068355
# 6869       -32.726028        86.314648         19.395493  ...       -0.068355
#
#       gaze_normal0_y  gaze_normal0_z  eye_center1_3d_x  eye_center1_3d_y  \
# 0          -0.254333        0.963599        -39.614250         12.749184
# 1          -0.254333        0.963599        -39.614250         12.749184
# 2          -0.254157        0.963541        -39.614250         12.749184
# 3          -0.254157        0.963541        -39.614250         12.749184
# 4          -0.254308        0.963443        -39.614250         12.749184
# ...              ...             ...               ...               ...
# 6865       -0.408561        0.910205        -38.378552         14.746163
# 6866       -0.406993        0.910935        -38.378552         14.746163
# 6867       -0.406993        0.910935        -38.378552         14.746163
# 6868       -0.407510        0.910639        -38.378552         14.746163
# 6869       -0.407510        0.910639        -38.378552         14.746163
#
#       eye_center1_3d_z  gaze_normal1_x  gaze_normal1_y  gaze_normal1_z  \
# 0           -21.421734        0.238430       -0.205235        0.949226
# 1           -21.421734        0.237066       -0.204610        0.949702
# 2           -21.421734        0.237066       -0.204610        0.949702
# 3           -21.421734        0.238125       -0.204719        0.949414
# 4           -21.421734        0.238125       -0.204719        0.949414
# ...                ...             ...             ...             ...
# 6865        -23.063852        0.384568       -0.364283        0.848178
# 6866        -23.063852        0.384568       -0.364283        0.848178
# 6867        -23.063852        0.384937       -0.365632        0.847430
# 6868        -23.063852        0.384937       -0.365632        0.847430
# 6869        -23.063852        0.384866       -0.364403        0.847991
#
#                       file
# 0     Task1_Subject_2.xlsx
# 1     Task1_Subject_2.xlsx
# 2     Task1_Subject_2.xlsx
# 3     Task1_Subject_2.xlsx
# 4     Task1_Subject_2.xlsx
# ...                    ...
# 6865  Task1_Subject_1.xlsx
# 6866  Task1_Subject_1.xlsx
# 6867  Task1_Subject_1.xlsx
# 6868  Task1_Subject_1.xlsx
# 6869  Task1_Subject_1.xlsx
#
# [316676 rows x 22 columns]

# %%
#Writing files into dataframes
df_cg3 = []

for file in files_xlsx:
    file_path = os.path.join(folder_path, file)
    #sheet name is how we are identifying different datasets, this needs to be updated each time
    data3 = pd.read_excel(file_path, sheet_name=2)
    file_name = os.path.basename(file_path)
    data3['file'] = file_name
    df_cg3.append(data3)

# Concatenate the list of DataFrames into a single DataFrame
c_gaze_task3 = pd.concat(df_cg3)

# %%
c_gaze_task3
# Out:
#        gaze_timestamp  world_index  confidence  norm_pos_x  norm_pos_y  \
# 0        91670.247971            0    0.998459    0.475548    0.639782
# 1        91670.251908            0    0.998189    0.475691    0.639476
# 2        91670.254956            0    0.998345    0.476355    0.638552
# 3        91670.258956            0    0.998482    0.476061    0.638676
# 4        91670.262869            0    0.998483    0.475302    0.638569
# ...               ...          ...         ...         ...         ...
# 17511     4997.139622          124    0.999078    0.541856    0.886705
# 17512     4997.143488          125    0.998858    0.541721    0.886522
# 17513     4997.147439          125    0.998956    0.541895    0.886558
# 17514     4997.151384          125    0.998831    0.541537    0.886783
# 17515     4997.155426          125    0.998769    0.541349    0.886776
#
#                                  base_data  gaze_point_3d_x  gaze_point_3d_y  \
# 0          '91670.245029-0 91670.250914-1'        -4.655001       -26.451901
# 1          '91670.252901-0 91670.250914-1'        -4.624563       -26.435742
# 2           '91670.252901-0 91670.25701-1'        -4.419598       -26.060148
# 3           '91670.260901-0 91670.25701-1'        -4.482211       -26.025836
# 4          '91670.260901-0 91670.264837-1'        -4.717111       -26.294437
# ...                                    ...              ...              ...
# 17511         '4997.137865-0 4997.14138-1'         6.902430       -36.040889
# 17512   '4997.145595999999-0 4997.14138-1'         6.878010       -36.001348
# 17513  '4997.145595999999-0 4997.149281-1'         6.893647       -35.953756
# 17514        '4997.153487-0 4997.149281-1'         6.828223       -35.901810
# 17515        '4997.153487-0 4997.157364-1'         6.811246       -35.956073
#
#        gaze_point_3d_z  eye_center0_3d_x  ...  gaze_normal0_x  gaze_normal0_y  \
# 0           149.884868         20.174258  ...       -0.141459       -0.253951
# 1           150.040660         20.174258  ...       -0.141173       -0.253393
# 2           148.651551         20.174258  ...       -0.141173       -0.253393
# 3           148.355215         20.174258  ...       -0.141763       -0.253761
# 4           149.967191         20.174258  ...       -0.141763       -0.253761
# ...                ...               ...  ...             ...             ...
# 17511        83.376708         20.401476  ...       -0.116341       -0.458165
# 17512        83.327658         20.401476  ...       -0.116616       -0.457946
# 17513        83.207561         20.401476  ...       -0.116616       -0.457946
# 17514        83.041239         20.401476  ...       -0.117343       -0.458299
# 17515        83.170400         20.401476  ...       -0.117343       -0.458299
#
#        gaze_normal0_z  eye_center1_3d_x  eye_center1_3d_y  eye_center1_3d_z  \
# 0            0.956817        -40.944510         13.382050        -18.530705
# 1            0.957007        -40.944510         13.382050        -18.530705
# 2            0.957007        -40.944510         13.382050        -18.530705
# 3            0.956822        -40.944510         13.382050        -18.530705
# 4            0.956822        -40.944510         13.382050        -18.530705
# ...               ...               ...               ...               ...
# 17511        0.881221        -38.620358         14.777856        -22.984815
# 17512        0.881298        -38.620358         14.777856        -22.984815
# 17513        0.881298        -38.620358         14.777856        -22.984815
# 17514        0.881018        -38.620358         14.777856        -22.984815
# 17515        0.881018        -38.620358         14.777856        -22.984815
#
#        gaze_normal1_x  gaze_normal1_y  gaze_normal1_z                  file
# 0            0.205020       -0.200992        0.957898  Task1_Subject_2.xlsx
# 1            0.205020       -0.200992        0.957898  Task1_Subject_2.xlsx
# 2            0.207778       -0.200357        0.957437  Task1_Subject_2.xlsx
# 3            0.207778       -0.200357        0.957437  Task1_Subject_2.xlsx
# 4            0.204625       -0.199278        0.958341  Task1_Subject_2.xlsx
# ...               ...             ...             ...                   ...
# 17511        0.359671       -0.389476        0.847906  Task1_Subject_1.xlsx
# 17512        0.359671       -0.389476        0.847906  Task1_Subject_1.xlsx
# 17513        0.360126       -0.389553        0.847678  Task1_Subject_1.xlsx
# 17514        0.360126       -0.389553        0.847678  Task1_Subject_1.xlsx
# 17515        0.359632       -0.389512        0.847906  Task1_Subject_1.xlsx
#
# [694484 rows x 22 columns]

# %%
#Writing files into dataframes
df_cg4 = []

for file in files_xlsx:
    file_path = os.path.join(folder_path, file)
    #sheet name is how we are identifying different datasets, this needs to be updated each time
    data4 = pd.read_excel(file_path, sheet_name=3)
    file_name = os.path.basename(file_path)
    data4['file'] = file_name
    df_cg4.append(data4)

# Concatenate the list of DataFrames into a single DataFrame
c_gaze_task4 = pd.concat(df_cg4)

# %%
c_gaze_task4
# Out:
#       gaze_timestamp  world_index  confidence  norm_pos_x  norm_pos_y  \
# 0       90995.126606            0    0.999002    0.411914    0.653381
# 1       90995.130476            0    0.999085    0.410307    0.652812
# 2       90995.134505            0    0.998822    0.410294    0.653307
# 3       90995.138530            0    0.999013    0.408774    0.653903
# 4       90995.142535            0    0.999305    0.408589    0.653556
# ...              ...          ...         ...         ...         ...
# 9272     5225.079725          358    0.999432    0.526826    0.740453
# 9273     5225.083664          359    0.999303    0.526852    0.740481
# 9274     5225.087568          359    0.999044    0.526362    0.740361
# 9275     5225.091694          359    0.999149    0.526143    0.739468
# 9276     5225.095672          359    0.999277    0.526692    0.739357
#
#                             base_data  gaze_point_3d_x  gaze_point_3d_y  \
# 0      '90995.124672-0 90995.12854-1'       -23.657088       -33.094082
# 1      '90995.132412-0 90995.12854-1'       -23.829218       -32.608353
# 2     '90995.132412-0 90995.136599-1'       -23.838587       -32.695155
# 3     '90995.140461-0 90995.136599-1'       -23.996110       -32.421654
# 4      '90995.140461-0 90995.14461-1'       -24.139091       -32.490129
# ...                               ...              ...              ...
# 9272    '5225.081953-0 5225.077498-1'         4.437673       -22.631132
# 9273    '5225.081953-0 5225.085376-1'         4.440193       -22.628284
# 9274     '5225.08976-0 5225.085376-1'         4.362628       -22.565556
# 9275     '5225.08976-0 5225.093629-1'         4.340613       -22.538773
# 9276    '5225.097715-0 5225.093629-1'         4.428030       -22.591263
#
#       gaze_point_3d_z  eye_center0_3d_x  ...  gaze_normal0_x  gaze_normal0_y  \
# 0          173.318342         18.887912  ...       -0.209130       -0.245185
# 1          171.206656         18.887912  ...       -0.212149       -0.245202
# 2          171.234396         18.887912  ...       -0.212149       -0.245202
# 3          169.237849         18.887912  ...       -0.214978       -0.246997
# 4          169.884261         18.887912  ...       -0.214978       -0.246997
# ...               ...               ...  ...             ...             ...
# 9272        82.386692         18.724212  ...       -0.128456       -0.363171
# 9273        82.367813         18.724212  ...       -0.128456       -0.363171
# 9274        82.178733         18.724212  ...       -0.129374       -0.363238
# 9275        82.351817         18.724212  ...       -0.129374       -0.363238
# 9276        82.573696         18.724212  ...       -0.128343       -0.362840
#
#       gaze_normal0_z  eye_center1_3d_x  eye_center1_3d_y  eye_center1_3d_z  \
# 0           0.946651        -39.524515         12.993659        -20.867728
# 1           0.945975        -39.524515         12.993659        -20.867728
# 2           0.945975        -39.524515         12.993659        -20.867728
# 3           0.944869        -39.524515         12.993659        -20.867728
# 4           0.944869        -39.524515         12.993659        -20.867728
# ...              ...               ...               ...               ...
# 9272        0.922825        -38.933029         15.263256        -22.073246
# 9273        0.922825        -38.933029         15.263256        -22.073246
# 9274        0.922670        -38.933029         15.263256        -22.073246
# 9275        0.922670        -38.933029         15.263256        -22.073246
# 9276        0.922971        -38.933029         15.263256        -22.073246
#
#       gaze_normal1_x  gaze_normal1_y  gaze_normal1_z                  file
# 0           0.079109       -0.212818        0.973884  Task1_Subject_2.xlsx
# 1           0.079109       -0.212818        0.973884  Task1_Subject_2.xlsx
# 2           0.079047       -0.213582        0.973722  Task1_Subject_2.xlsx
# 3           0.079047       -0.213582        0.973722  Task1_Subject_2.xlsx
# 4           0.078062       -0.212770        0.973979  Task1_Subject_2.xlsx
# ...              ...             ...             ...                   ...
# 9272        0.363209       -0.303075        0.881036  Task1_Subject_1.xlsx
# 9273        0.363282       -0.303129        0.880988  Task1_Subject_1.xlsx
# 9274        0.363282       -0.303129        0.880988  Task1_Subject_1.xlsx
# 9275        0.362664       -0.301810        0.881695  Task1_Subject_1.xlsx
# 9276        0.362664       -0.301810        0.881695  Task1_Subject_1.xlsx
#
# [641714 rows x 22 columns]

# %%
#Writing files into dataframes
df_cpt1 = []

for file in files_xlsx:
    file_path = os.path.join(folder_path, file)
    #sheet name is how we are identifying different datasets, this needs to be updated each time
    data5 = pd.read_excel(file_path, sheet_name=4)
    file_name = os.path.basename(file_path)
    data5['file'] = file_name
    df_cpt1.append(data5)

# Concatenate the list of DataFrames into a single DataFrame
c_pupil_task1 = pd.concat(df_cpt1)

# %%
c_pupil_task1
# Out:
#        pupil_timestamp world_index  eye_id  confidence  norm_pos_x norm_pos_y  \
# 0         91462.401039           0     0.0    0.999429    0.187397   0.364985
# 1         91462.401039           0     0.0    1.000000    0.187403   0.364949
# 2         91462.401180           0     1.0    1.000000    0.363595   0.801304
# 3         91462.401180           0     1.0    0.999971    0.363605   0.801323
# 4         91462.408708           0     0.0    1.000000    0.186701   0.364562
# ...                ...         ...     ...         ...         ...        ...
# 16401      5444.350231         236     0.0    0.390900    0.344971   0.408262
# 16402      5444.353666         236     1.0    0.012059    0.293754   0.645838
# 16403      5444.353666         236     1.0    0.657261    0.415161    0.68318
# 16404      5444.357724         236     0.0    0.451749    0.348017   0.405874
# 16405      5444.357724         236     0.0    0.491462    0.361707    0.38647
#
#         diameter    method  ellipse_center_x  ellipse_center_y  ...  \
# 0      29.110555  '3d c++'         35.980209        121.922834  ...
# 1      29.111584  '2d c++'         35.981316        121.929710  ...
# 2      29.077452  '2d c++'         69.810272         38.149712  ...
# 3      29.084270  '3d c++'         69.812133         38.145988  ...
# 4      28.808062  '2d c++'         35.846523        122.004143  ...
# ...          ...       ...               ...               ...  ...
# 16401  41.681687  '3d c++'         66.234522        113.613751  ...
# 16402  37.875454  '3d c++'         56.400790         67.999047  ...
# 16403  42.941853  '2d c++'         79.710823         60.829433  ...
# 16404  41.828486  '3d c++'         66.819291        114.072207  ...
# 16405  50.528824  '2d c++'         69.447792        117.797821  ...
#
#        circle_3d_normal_z  circle_3d_radius     theta       phi  \
# 0               -0.769590          1.697848  1.837903 -2.217815
# 1                     NaN               NaN       NaN       NaN
# 2                     NaN               NaN       NaN       NaN
# 3               -0.800517          1.627410  1.366736 -2.184574
# 4                     NaN               NaN       NaN       NaN
# ...                   ...               ...       ...       ...
# 16401           -0.742988          2.072740  1.741944 -2.287456
# 16402           -0.432488          2.093285  1.492193 -2.692856
# 16403                 NaN               NaN       NaN       NaN
# 16404           -0.746656          2.076740  1.745615 -2.281026
# 16405                 NaN               NaN       NaN       NaN
#
#        projected_sphere_center_x  projected_sphere_center_y  \
# 0                      95.602904                  95.147140
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                     121.698304                  68.007389
# 4                            NaN                        NaN
# ...                          ...                        ...
# 16401                 132.126213                  93.909540
# 16402                 144.993477                  79.293435
# 16403                        NaN                        NaN
# 16404                 132.126213                  93.909540
# 16405                        NaN                        NaN
#
#        projected_sphere_axis_a  projected_sphere_axis_b  \
# 0                   160.735567               160.735567
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                   163.387068               163.387068
# 4                          NaN                      NaN
# ...                        ...                      ...
# 16401               183.073010               183.073010
# 16402               185.440376               185.440376
# 16403                      NaN                      NaN
# 16404               183.073010               183.073010
# 16405                      NaN                      NaN
#
#        projected_sphere_angle                  file
# 0                        90.0  Task1_Subject_2.xlsx
# 1                         NaN  Task1_Subject_2.xlsx
# 2                         NaN  Task1_Subject_2.xlsx
# 3                        90.0  Task1_Subject_2.xlsx
# 4                         NaN  Task1_Subject_2.xlsx
# ...                       ...                   ...
# 16401                    90.0  Task1_Subject_1.xlsx
# 16402                    90.0  Task1_Subject_1.xlsx
# 16403                     NaN  Task1_Subject_1.xlsx
# 16404                    90.0  Task1_Subject_1.xlsx
# 16405                     NaN  Task1_Subject_1.xlsx
#
# [819590 rows x 35 columns]

# %%
import torch

if torch.cuda.is_available():
  print("GPU available")
else:
  print("GPU not available")
# Out:
# GPU available
